# %%
import pandas as pd
import numpy as np
import os

# %%
data = lambda x: os.path.join('../../data/tokped/sayur-buah/', x)

# %%
df_full = pd.read_json(data('products_full.jsonlines'), lines=True)
df_init = pd.read_json(data('products.jsonlines'), lines=True)

# %%
df = pd.merge(df_init, df_full, on='id')
df
# Out:
#                 id                                             name_x  \
# 0       1587682381     PAKCOY / POKCOY / PAK COY SAYUR [1 Ikat] FRESH
# 1        993150756                  ABOVE x SUKA Garlic Power - 350ml
# 2       1089165689                        Daun Ketumbar/Wansui -100gr
# 3        719647346  Pakcoy Sayur Fresh Segar 500gr Pasar Murah Ban...
# 4        587565795                   BABY CARROT / WORTEL MINI [500g]
# ...            ...                                                ...
# 327206  1060720469                        Daun Seledri Lokal 1 packet
# 327207   834396396                                 Seledri stik lokal
# 327208  1228915899                                 Daun seledri lokal
# 327209  1821407746  Kurma Ajwa Dlight Premium Madinah Kurma Nabi L...
# 327210  1728354480  Pasti Murah Kurma Anggur/Bam-Muzafati-750Gr-Gr...
#
#                            category_breadcrumb  \
# 0           makanan-minuman/sayur-buah/sayuran
# ...
