# %%
import spacy
import pandas as pd
import numpy as np
from tqdm import tqdm
from signal import signal, SIGPIPE, SIG_DFL
import re
import json

# %%
import os
import sys
sys.path.append('../')

from nlp.lemmatizer import LOOKUP
from nlp.noise_words import noise_words

# %%
from signal import signal, SIGPIPE, SIG_DFL

# %%
df = pd.read_json('../../data/tokped/susu/products.json')

# %%
def cleaning_title(doc):
    text = [token.text if token not in LOOKUP.items()
            else LOOKUP[token]
            for token in doc
            if not token.is_stop
            and token.text not in noise_words
            and len(token.text) > 2
            ]
    if len(text) > 2:
        return ' '.join(text)

# %%
nlp = spacy.blank('id')
brief_cleaning = [re.sub("[^A-Za-z']+", ' ', str(title)).lower()
                      for title in df.name.values]

# %%
text = [cleaning_title(doc) for doc in tqdm(
        nlp.pipe(brief_cleaning, batch_size=5000, n_process=-1))]
# Out:
# 331634it [01:04, 5174.43it/s]

# %%
titles = [title.split() for title in text if title is not None]
words = np.array([word for title in tqdm(titles)
                 for word in title], dtype=object)
# Out:
# 100%|██████████| 298570/298570 [00:00<00:00, 4125207.43it/s]

# %%
from collections import Counter
counter = Counter(words)

# %%
import json
with open('keyword_counter.json', 'w') as f:
    json.dump(dict(counter), f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-21004cee7780> in <module>
#       1 import json
#       2 f = open('keyword_counter.json', 'w')
# ----> 3 json.dump(dict(counter), f)
#
# NameError: name 'counter' is not defined

# %%
keywords = [k[0] for k in counter.most_common(20)]
keywords
# Out:
# ['susu',
#  'milk',
#  'keju',
#  'cream',
#  'isi',
#  'coklat',
#  'cheese',
#  'butter',
#  'uht',
#  'bubuk',
#  'sachet',
#  'gold',
#  'liter',
#  'almond',
#  'cheddar',
#  'vanila',
#  'repack',
#  'full',
#  'madu',
#  'kambing']

# %%
titles = np.array(titles, dtype=object)

# %%
def keyword_pairs(keywords, n_common=20, threshold=100):
    for k in keywords:
        # find prods which contain the keyword and find second most common
        contains_k = titles[np.array([k in name for name in titles])]
        words = [word for name in contains_k for word in name]
        k_counter = Counter(words)
        most_common = k_counter.most_common(n_common)
        for key in most_common:
            if k != key[0] and key[1] > 100:
                yield k + ' ' + key[0]

# %%
f = open('../../data/tokped/susu/keywords.json', 'w')
json.dump(list(keyword_pairs(keywords)), f)

# %%
data = list(keyword_pairs(keywords))

# %%
len(json.dumps([{"value": k, "name": f"query: {k}"} for k in data]))
# Out:
# 21702

# %%
df_keywords_loader = pd.read_json('../../data/tokped/susu/keyword_search.jsonlines', chunksize=10000, lines=True)
df_keywords = pd.concat([dataframe for dataframe in tqdm(df_keywords_loader, total=1358952/10000)])
# Out:
#  99%|█████████▊| 134/135.8952 [00:13<00:00, 13.42it/s]/Users/williamtan/miniforge3/envs/item-clustering/lib/python3.8/site-packages/tqdm/std.py:532: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# 100%|██████████| 136/135.8952 [00:13<00:00,  9.92it/s]

# %%
df_total = pd.concat([df_keywords.drop_duplicates(subset='id'), df]).drop_duplicates(subset='id')

# %%
df_total['sub_category'] = df_total.apply(lambda x: x.category_breadcrumb.split('/')[-1], axis=1)

# %%
df_total['sub_category'] = df_total.apply(lambda x: '-'.join([split for split in re.split(r" |\-|&", x.sub_category.lower()) if split != '']), axis=1)

# %%
df_total['shop_name'] = df_total.apply(lambda x: re.findall(r'(?<=https:\/\/www.tokopedia.com\/)(.*)(?=\/)', x.prod_url)[0], axis=1)

# %%
df_total
# Out:
#                   id                                               name  \
# shop_id
# 11440402  1874783778         ETAWAKU PLATINUM 3pcs - susu kambing etawa
# 11544205  1871554960        Susu Kambing Etawa Murni - Etawaku Platinum
# 11544205  1871551276  susu kambing etawa murni - Etawaku Platinum (p...
# 10778193  1870129638                          Susu Kambing Etawa Gomars
# 11547950  1864859469        susu kambing etawa HMS coletrum (1 bungkus)
# ...              ...                                                ...
# 6391989    617562924                                  Susu Dancow Putih
# 3473756    566442284  KUAS MENTEGA KUAS ROTI SILIKON CAKE BARBEQUE 1...
# 179367       5224388                                Amino X - 70serving
# 4863938    373378032                                  alat pembusa susu
# 4714559    825614294                  Vidoran Xmart 3+ - Vanilla - 725g
#
#                                      category_breadcrumb  \
# shop_id
# 11440402          makanan-minuman/produk-susu/susu-bubuk
# 11544205          makanan-minuman/produk-susu/susu-bubuk
# 11544205          makanan-minuman/produk-susu/susu-bubuk
# 10778193          makanan-minuman/produk-susu/susu-bubuk
# 11547950          makanan-minuman/produk-susu/susu-bubuk
# ...                                                  ...
# 6391989         Makanan & Minuman/Produk Susu/Susu Bubuk
# 3473756   Makanan & Minuman/Produk Susu/Mentega & Butter
# 179367          Makanan & Minuman/Produk Susu/Susu Bubuk
# 4863938         Makanan & Minuman/Produk Susu/Susu Bubuk
# 4714559         Makanan & Minuman/Produk Susu/Susu Bubuk
#
#                                                    prod_url  old_price  \
# shop_id
# 11440402  https://www.tokopedia.com/etawakustore-1/etawa...        NaN
# 11544205  https://www.tokopedia.com/silostore93/susu-kam...        NaN
# 11544205  https://www.tokopedia.com/silostore93/susu-kam...        NaN
# 10778193  https://www.tokopedia.com/rumahherbalamanah/su...        NaN
# 11547950  https://www.tokopedia.com/fujjolshop-1/susu-ka...        NaN
# ...                                                     ...        ...
# 6391989   https://www.tokopedia.com/sembako-mandiri/susu...        0.0
# 3473756   https://www.tokopedia.com/wjcol/kuas-mentega-k...        0.0
# 179367    https://www.tokopedia.com/suplemen-fitness/ami...        0.0
# 4863938   https://www.tokopedia.com/lapakempatsatu/alat-...        0.0
# 4714559   https://www.tokopedia.com/archive-awku/vidoran...        0.0
#
#           discounted_price  discount_percent   stock  \
# shop_id
# 11440402            210000                 0       6
# 11544205             73000                 0      87
# 11544205            140000                 0      49
# 10778193             17000                 0      60
# 11547950             10000                 0     417
# ...                    ...               ...     ...
# 6391989              31423                 0    9990
# 3473756               2600                 0  999995
# 179367             1120000                 0  999999
# 4863938              50000                 0  999999
# 4714559              43000                 0      20
#
#                                                  image_urls  review_count  \
# shop_id
# 11440402  [https://images.tokopedia.net/img/cache/200-sq...             1
# 11544205  [https://images.tokopedia.net/img/cache/200-sq...             2
# 11544205  [https://images.tokopedia.net/img/cache/200-sq...             1
# 10778193  [https://images.tokopedia.net/img/cache/200-sq...             2
# 11547950  [https://images.tokopedia.net/img/cache/200-sq...             2
# ...                                                     ...           ...
# 6391989   [https://ecs7-p.tokopedia.net/img/cache/250-sq...             3
# 3473756   [https://ecs7-p.tokopedia.net/img/cache/250-sq...             1
# 179367    [https://ecs7-p.tokopedia.net/img/cache/250-sq...             1
# 4863938   [https://ecs7-p.tokopedia.net/img/cache/250-sq...             6
# 4714559   [https://ecs7-p.tokopedia.net/img/cache/250-sq...             1
#
#           rating  sold                                                ref  \
# shop_id
# 11440402     5.0     4  device=desktop&rows=200&source=universal&sc=26...
# 11544205     5.0    20  device=desktop&rows=200&source=universal&sc=26...
# 11544205     5.0     1  device=desktop&rows=200&source=universal&sc=26...
# 10778193     5.0    40  device=desktop&rows=200&source=universal&sc=26...
# 11547950     5.0     6  device=desktop&rows=200&source=universal&sc=26...
# ...          ...   ...                                                ...
# 6391989      5.0    10  {'from': '1604474023', 'section': 'Pilihan lai...
# 3473756      5.0     4  {'from': '281335192', 'section': 'Produk spons...
# 179367       3.0     0  {'from': '5224406', 'section': 'Produk sponsor...
# 4863938      5.0    16  {'from': '1022486913', 'section': 'Produk spon...
# 4714559      5.0     4  {'from': '830679778', 'section': 'Pilihan lain...
#
#             sub_category          shop_name
# shop_id
# 11440402      susu-bubuk     etawakustore-1
# 11544205      susu-bubuk        silostore93
# 11544205      susu-bubuk        silostore93
# 10778193      susu-bubuk  rumahherbalamanah
# 11547950      susu-bubuk       fujjolshop-1
# ...                  ...                ...
# 6391989       susu-bubuk    sembako-mandiri
# 3473756   mentega-butter              wjcol
# 179367        susu-bubuk   suplemen-fitness
# 4863938       susu-bubuk     lapakempatsatu
# 4714559       susu-bubuk       archive-awku
#
# [137219 rows x 15 columns]

# %%
df_total = df_total.rename(columns={'shop': 'shop_id'})

# %%
# find non produk-susu products
df_total[df_total.apply(lambda x: len(x.category_breadcrumb.split('/')) != 3 or (x.category_breadcrumb.split('/')[-2] != 'Produk Susu' and x.category_breadcrumb.split('/')[-2] != 'produk-susu'), axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, name, category_breadcrumb, prod_url, old_price, discounted_price, discount_percent, stock, shop, image_urls, review_count, rating, sold, ref, sub_category, shop_name]
# Index: []

# %%
df_total = df_total.reset_index(drop=True)

# %%
df_total.to_json('../../data/tokped/susu/products_final.json')

# %%
# find sellers
unique_shop_id = df_total.index.unique()

# %%
df_total = df_total.set_index('shop_id')

# %%
df_total.loc[unique_shop_id[0]].iloc[0].shop_name
# Out:
# 'etawakustore-1'

# %%
unique_shop_name = [df_total.loc[id].iloc[0].shop_name for id in tqdm(unique_shop_id)]
# Out:
#   0%|          | 0/16974 [00:00<?, ?it/s]
#
#
#   1%|          | 210/16974 [00:00<00:08, 2094.31it/s]
#
#
#   3%|▎         | 477/16974 [00:00<00:06, 2424.64it/s]
#
#
#   4%|▍         | 754/16974 [00:00<00:06, 2579.13it/s]
#
#
#   6%|▋         | 1083/16974 [00:00<00:05, 2857.11it/s]
#
#
#   8%|▊         | 1417/16974 [00:00<00:05, 3029.56it/s]
#
#
#  10%|█         | 1760/16974 [00:00<00:04, 3165.13it/s]
#
#
#  12%|█▏        | 2116/16974 [00:00<00:04, 3293.33it/s]
#
#
#  15%|█▍        | 2493/16974 [00:00<00:04, 3443.97it/s]
#
#
#  17%|█▋        | 2869/16974 [00:00<00:03, 3542.53it/s]
#
#
#  19%|█▉        | 3224/16974 [00:01<00:03, 3530.98it/s]
#
#
#  21%|██        | 3578/16974 [00:01<00:03, 3425.83it/s]
#
#
#  23%|██▎       | 3958/16974 [00:01<00:03, 3534.04it/s]
#
#
#  26%|██▌       | 4359/16974 [00:01<00:03, 3673.55it/s]
#
#
#  28%|██▊       | 4751/16974 [00:01<00:03, 3746.23it/s]
#
#
#  30%|███       | 5127/16974 [00:01<00:03, 3688.19it/s]
#
#
#  32%|███▏      | 5497/16974 [00:01<00:03, 3684.25it/s]
#
#
#  35%|███▍      | 5866/16974 [00:01<00:03, 3683.29it/s]
#
#
#  37%|███▋      | 6239/16974 [00:01<00:02, 3696.86it/s]
#
#
#  39%|███▉      | 6629/16974 [00:01<00:02, 3756.59it/s]
#
#
#  41%|████▏     | 7005/16974 [00:02<00:02, 3757.24it/s]
#
#
#  44%|████▎     | 7394/16974 [00:02<00:02, 3795.71it/s]
#
#
#  46%|████▌     | 7774/16974 [00:02<00:02, 3774.24it/s]
#
#
#  48%|████▊     | 8152/16974 [00:02<00:02, 3699.93it/s]
#
#
#  50%|█████     | 8543/16974 [00:02<00:02, 3761.01it/s]
#
#
#  53%|█████▎    | 8920/16974 [00:02<00:02, 3761.83it/s]
#
#
#  55%|█████▍    | 9315/16974 [00:02<00:02, 3816.81it/s]
#
#
#  57%|█████▋    | 9718/16974 [00:02<00:01, 3878.70it/s]
#
#
#  60%|█████▉    | 10112/16974 [00:02<00:01, 3894.03it/s]
#
#
#  62%|██████▏   | 10507/16974 [00:02<00:01, 3908.35it/s]
#
#
#  64%|██████▍   | 10905/16974 [00:03<00:01, 3927.86it/s]
#
#
#  67%|██████▋   | 11298/16974 [00:03<00:01, 3912.46it/s]
#
#
#  69%|██████▉   | 11700/16974 [00:03<00:01, 3943.41it/s]
#
#
#  71%|███████▏  | 12120/16974 [00:03<00:01, 4019.60it/s]
#
#
#  74%|███████▍  | 12561/16974 [00:03<00:01, 4136.27it/s]
#
#
#  76%|███████▋  | 12975/16974 [00:03<00:00, 4018.72it/s]
#
#
#  79%|███████▉  | 13421/16974 [00:03<00:00, 4146.87it/s]
#
#
#  82%|████████▏ | 13874/16974 [00:03<00:00, 4259.17it/s]
#
#
#  84%|████████▍ | 14305/16974 [00:03<00:00, 4273.24it/s]
#
#
#  87%|████████▋ | 14767/16974 [00:03<00:00, 4375.81it/s]
#
#
#  90%|████████▉ | 15215/16974 [00:04<00:00, 4406.38it/s]
#
#
#  92%|█████████▏| 15691/16974 [00:04<00:00, 4510.51it/s]
#
#
#  95%|█████████▌| 16163/16974 [00:04<00:00, 4572.30it/s]
#
#
# 100%|██████████| 16974/16974 [00:04<00:00, 3843.36it/s]

# %%
shop_df = df_total.copy()
shop_df

# %%
shop_df.columns
# Out:
# Index(['id', 'name', 'category_breadcrumb', 'prod_url', 'old_price',
#        'discounted_price', 'discount_percent', 'stock', 'image_urls',
#        'review_count', 'rating', 'sold', 'ref', 'sub_category', 'shop_name'],
#       dtype='object')

# %%
shop_df = shop_df.drop(columns=['id', 'name', 'category_breadcrumb', 'prod_url', 'old_price',
       'discounted_price', 'discount_percent', 'stock', 'image_urls',
       'review_count', 'rating', 'sold', 'ref', 'sub_category'])

# %%
shop_df = shop_df.drop_duplicates()

# %%
shop_df.to_json("../../data/tokped/susu/sellers.json")

# %%
df_total.loc[11440402]
# Out:
#                   id                                               name  \
# shop_id
# 11440402  1874783778         ETAWAKU PLATINUM 3pcs - susu kambing etawa
# 11440402  1827694242  etawaku platinum 2box - susu kambing murni ber...
# 11440402  1827692240      etawaku platinum - susu kambing murni bergizi
# 11440402  1873500436                 ETAWAKU PLATINUM 5 box ready stock
# 11440402  1851165091         Susu daymilk - susu kambing etawa - Vanila
# 11440402  1874802065  ETAWAKU PLATIKUM 10box - susu kambing etawa murni
#
#                                         category_breadcrumb  \
# shop_id
# 11440402             makanan-minuman/produk-susu/susu-bubuk
# 11440402             makanan-minuman/produk-susu/susu-bubuk
# 11440402             makanan-minuman/produk-susu/susu-bubuk
# 11440402           Makanan & Minuman/Produk Susu/Susu Bubuk
# 11440402           Makanan & Minuman/Produk Susu/Susu Bubuk
# 11440402  Makanan & Minuman/Produk Susu/Susu segar & Pas...
#
#                                                    prod_url  old_price  \
# shop_id
# 11440402  https://www.tokopedia.com/etawakustore-1/etawa...        NaN
# 11440402  https://www.tokopedia.com/etawakustore-1/etawa...        NaN
# 11440402  https://www.tokopedia.com/etawakustore-1/etawa...        NaN
# 11440402  https://www.tokopedia.com/etawakustore-1/etawa...        0.0
# 11440402  https://www.tokopedia.com/etawakustore-1/susu-...        0.0
# 11440402  https://www.tokopedia.com/etawakustore-1/etawa...        0.0
#
#           discounted_price  discount_percent  stock  \
# shop_id
# 11440402            210000                 0      6
# 11440402            140000                 0     44
# 11440402             75000                 0     95
# 11440402            350000                 0      9
# 11440402             25000                 0      1
# 11440402            660000                 0     10
#
#                                                  image_urls  review_count  \
# shop_id
# 11440402  [https://images.tokopedia.net/img/cache/200-sq...             1
# 11440402  [https://images.tokopedia.net/img/cache/200-sq...             4
# 11440402  [https://images.tokopedia.net/img/cache/200-sq...             1
# 11440402  [https://ecs7-p.tokopedia.net/img/cache/250-sq...             0
# 11440402  [https://ecs7-p.tokopedia.net/img/cache/250-sq...             0
# 11440402  [https://ecs7-p.tokopedia.net/img/cache/250-sq...             0
#
#           rating  sold                                                ref  \
# shop_id
# 11440402     5.0     4  device=desktop&rows=200&source=universal&sc=26...
# 11440402     5.0    22  device=desktop&rows=200&source=universal&sc=26...
# 11440402     5.0     5  device=desktop&rows=200&source=universal&sc=26...
# 11440402     0.0     1  {'from': '1874783778', 'section': 'Lainnya di ...
# 11440402     0.0     0  {'from': '1874783778', 'section': 'Lainnya di ...
# 11440402     0.0     0  {'from': '1874783778', 'section': 'Lainnya di ...
#
#                      sub_category       shop_name
# shop_id
# 11440402               susu-bubuk  etawakustore-1
# 11440402               susu-bubuk  etawakustore-1
# 11440402               susu-bubuk  etawakustore-1
# 11440402               susu-bubuk  etawakustore-1
# 11440402               susu-bubuk  etawakustore-1
# 11440402  susu-segar-pasteurisasi  etawakustore-1

# %%
shop_df
# Out:
#                   shop_name
# shop_id
# 11440402     etawakustore-1
# 11544205        silostore93
# 10778193  rumahherbalamanah
# 11547950       fujjolshop-1
# 11549673      mamafaizstore
# ...                     ...
# 4179132           ryotakise
# 8859878       tokoadekaka-1
# 3769682      fadlinabawi910
# 3385766          decko-hulu
# 4863938      lapakempatsatu
#
# [16974 rows x 1 columns]

# %%
# %time df_total.loc[11440402].iloc[0]
# Out:
# CPU times: user 1.6 ms, sys: 851 µs, total: 2.45 ms
# Wall time: 1.54 ms
# id                                                            1874783778
# name                          ETAWAKU PLATINUM 3pcs - susu kambing etawa
# category_breadcrumb               makanan-minuman/produk-susu/susu-bubuk
# prod_url               https://www.tokopedia.com/etawakustore-1/etawa...
# old_price                                                            NaN
# discounted_price                                                  210000
# discount_percent                                                       0
# stock                                                                  6
# image_urls             [https://images.tokopedia.net/img/cache/200-sq...
# review_count                                                           1
# rating                                                               5.0
# sold                                                                   4
# ref                    device=desktop&rows=200&source=universal&sc=26...
# sub_category                                                  susu-bubuk
# shop_name                                                 etawakustore-1
# Name: 11440402, dtype: object
